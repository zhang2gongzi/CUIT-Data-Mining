# %%
import pandas as pd

# %%
# 尝试读取文件，跳过错误行
df = pd.read_csv("年度数据房价平均销售价格.csv", encoding='gbk')

# %%
print(df)
# Out:
#                      指标    2022年     2021年     2020年     2019年     2018年  \
# 0      商品房平均销售价格(元/平方米)   9991.0  10322.67  10030.17   9469.42   8859.18
# 1    住宅商品房平均销售价格(元/平方米)  10375.0  10589.94  10158.94   9454.35   8694.14
# 2  别墅、高档公寓平均销售价格(元/平方米)      NaN       NaN       NaN  17886.00  16252.00
# 3   办公楼商品房平均销售价格(元/平方米)  14003.0  14060.30  15263.90  14430.66  14470.55
# 4   商业营业用房平均销售价格(元/平方米)   9934.0  10792.03  10711.84  11017.00  10948.30
# 5    其他商品房平均销售价格(元/平方米)   4081.0   4648.84   4848.80   5139.08   5394.58
#
#       2017年     2016年     2015年     2014年     2013年     2012年     2011年  \
# 0   8008.11   7565.00   6854.72   6369.76   6274.49   5816.11   5365.50
# 1   7736.96   7297.56   6542.51   5988.25   5893.78   5462.98   5010.30
# 2  14965.00  15911.00  15157.00  12965.00  12591.00  11460.19  10993.92
# 3  13620.46  14375.57  12914.34  11825.93  12996.53  12306.41  12327.28
# 4  10359.46   9794.57   9547.23   9780.02   9727.48   8960.59   8408.20
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_transposed = df.transpose()

# %%
# 查看转置后的数据前几行
print("\n转置后的数据:")
print(df_transposed.head())

# 重置索引（可选）
df_transposed = df_transposed.reset_index()

# 查看转置后的数据前几行
print("\n重置索引后的数据:")
print(df_transposed.head())

# 保存转置后的数据到新的CSV文件（可选）
df_transposed.to_csv('年度数据房价平均销售价格_转置.csv', index=False)
# Out:
# 转置后的数据:
#                       0                   1                     2  \
# 指标     商品房平均销售价格(元/平方米)  住宅商品房平均销售价格(元/平方米)  别墅、高档公寓平均销售价格(元/平方米)
# 2022年            9991.0             10375.0                   NaN
# 2021年          10322.67            10589.94                   NaN
# 2020年          10030.17            10158.94                   NaN
# 2019年           9469.42             9454.35               17886.0
#
#                          3                    4                   5
# 指标     办公楼商品房平均销售价格(元/平方米)  商业营业用房平均销售价格(元/平方米)  其他商品房平均销售价格(元/平方米)
# 2022年              14003.0               9934.0              4081.0
# 2021年              14060.3             10792.03             4648.84
# 2020年              15263.9             10711.84              4848.8
# 2019年             14430.66              11017.0             5139.08
#
# 重置索引后的数据:
#    index                 0                   1                     2  \
# ...

# %%
# 加载CSV文件
df = pd.read_csv('年度数据房价平均销售价格_转置.csv', encoding='gbk')

# 查看数据前几行
print(df.head())
# Out:
#      年份       商品房     住宅商品房  别墅、高档公寓    办公楼商品房    商业营业用房    其他商品房
# 0  2022   9991.00  10375.00      NaN  14003.00   9934.00  4081.00
# 1  2021  10322.67  10589.94      NaN  14060.30  10792.03  4648.84
# 2  2020  10030.17  10158.94      NaN  15263.90  10711.84  4848.80
# 3  2019   9469.42   9454.35  17886.0  14430.66  11017.00  5139.08
# 4  2018   8859.18   8694.14  16252.0  14470.55  10948.30  5394.58

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 加载CSV文件
df = pd.read_csv('年度数据房价平均销售价格_转置.csv', encoding='gbk')

# 使用已加载的数据框
data = df

# 提取年份作为 X 轴
years = data['年份']

# 删除 '年份' 列，只保留价格数据
price_data = data.drop(columns=['年份'])

# 创建图形
plt.figure(figsize=(10, 6))

# 绘制每种类型的折线图
for column in price_data.columns:
    plt.plot(years, price_data[column], label=column)
# 设置 X 轴刻度，显示每年的数据
plt.xticks(years, rotation=45)  # 旋转45度以防止标签重叠

# 添加标题和轴标签
plt.title('Trend of average sales prices of various types of commercial housing over the years')
plt.xlabel('year')
plt.ylabel('price/m^2')

# 添加图例
plt.legend()

# 显示网格
plt.grid(True)

# 显示图表
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# 提供的数据点
x_data = [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
y_data = [5576, 5833.95, 6584.93, 7471.25, 7801, 9662, 10934, 10993.92, 11460.19, 12591, 12965, 15157, 15911, 14965, 16252, 17886]

# 将数据转换为NumPy数组
X_train = np.array(x_data).reshape(-1, 1)
y_train = np.array(y_data).reshape(-1, 1)

# 创建并训练线性回归模型
model = LinearRegression()
model.fit(X_train, y_train)

# 预测未来的两个数据点
future_points = np.array([2020, 2021,2022]).reshape(-1, 1)
predictions = model.predict(future_points)

print("预测的未来两个数据点:", predictions.flatten())
# Out:
# 预测的未来两个数据点: [18398.608      19224.58952941 20050.57105882]
